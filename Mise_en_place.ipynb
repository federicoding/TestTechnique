# %% [markdown]
# <a href="https://colab.research.google.com/github/federicoding/TestTechnique/blob/main/Mise_en_place.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Creation de la DB

# %%
# Instaling PyMongo, this is the interface to connect to MongoDB with Python
! python -m pip install pymongo==3.7.2
# Out:
# ...
#      |████████████████████████████████| 406 kB 5.7 MB/s
# ...
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 3.11.4
#     Uninstalling pymongo-3.11.4:
#       Successfully uninstalled pymongo-3.11.4
# ...

# %% [markdown]
# #Etablissement de la connection

# %%
import pymongo
from pymongo import MongoClient

# uri (uniform resource identifier) pour définir les paramètres de connection

uri = 'mongodb://uza9ynmsdmyniep56h8j:wg83aPoB4is0aerB6vB9@bp6hfvjodoblv07-mongodb.services.clever-cloud.com:27017/bp6hfvjodoblv07'

# on start le client pour se connecter au serveur MongoDB
client = MongoClient(uri)

# %%
client.stats
# Out:
# Database(MongoClient(host=['bp6hfvjodoblv07-mongodb.services.clever-cloud.com:27017'], document_class=dict, tz_aware=False, connect=True), 'stats')

# %% [markdown]
# #Vérifications de base

# %%
client.list_database_names()
# Out:
# []

# %% [markdown]
# C'est bien vide pour l'instant.
# On va créer la db.

# %%
db = client.bp6hfvjodoblv07

# %%
client.list_database_names()
# Out:
# []

# %%
#on va créer la collection

db.create_collection('Transactions')
# Out:
# Collection(Database(MongoClient(host=['bp6hfvjodoblv07-mongodb.services.clever-cloud.com:27017'], document_class=dict, tz_aware=False, connect=True), 'bp6hfvjodoblv07'), 'Transactions')

# %%
collection = db.Transactions

# %% [markdown]
# On va importer les datas

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/federicoding/TestTechnique/main/Online_Retail.csv'
df = pd.read_csv(filepath_or_buffer=url, 
                 sep=';')

# %%
df
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]

# %%
data = df.to_dict('records')

# %%
data
# Out:
# [{'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
#   'Description': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'InvoiceDate': '01/12/2010 08:26',
#   'InvoiceNo': '536365',
#   'Quantity': 6,
#   'StockCode': '85123A',
#   'UnitPrice': '2,55'},
#  {'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
#   'Description': 'WHITE METAL LANTERN',
#   'InvoiceDate': '01/12/2010 08:26',
#   'InvoiceNo': '536365',
#   'Quantity': 6,
#   'StockCode': '71053',
#   'UnitPrice': '3,39'},
#  {'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
#   'Description': 'CREAM CUPID HEARTS COAT HANGER',
#   'InvoiceDate': '01/12/2010 08:26',
#   'InvoiceNo': '536365',
#   'Quantity': 8,
#   'StockCode': '84406B',
#   'UnitPrice': '2,75'},
#  {'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
#   'Description': 'KNITTED UNION FLAG HOT WATER BOTTLE',
#   'InvoiceDate': '01/12/2010 08:26',
#   'InvoiceNo': '536365',
#   'Quantity': 6,
#   'StockCode': '84029G',
# ...

# %%
collection.insert_many(data)

# %%
list(collection.find())
# Out:
# [{'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
#   'Description': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'InvoiceDate': '01/12/2010 08:26',
#   'InvoiceNo': '536365',
#   'Quantity': 6,
#   'StockCode': '85123A',
#   'UnitPrice': '2,55',
#   '_id': ObjectId('60f9941c13c427003cfce89e')},
#  {'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
#   'Description': 'WHITE METAL LANTERN',
#   'InvoiceDate': '01/12/2010 08:26',
#   'InvoiceNo': '536365',
#   'Quantity': 6,
#   'StockCode': '71053',
#   'UnitPrice': '3,39',
#   '_id': ObjectId('60f9941c13c427003cfce89f')},
#  {'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
#   'Description': 'CREAM CUPID HEARTS COAT HANGER',
#   'InvoiceDate': '01/12/2010 08:26',
#   'InvoiceNo': '536365',
#   'Quantity': 8,
#   'StockCode': '84406B',
#   'UnitPrice': '2,75',
#   '_id': ObjectId('60f9941c13c427003cfce8a0')},
#  {'Country': 'United Kingdom',
#   'CustomerID': 17850.0,
# ...
